# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoFoncescaFinardi/DA_IA_IOT/blob/main/BeactReport_att_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **COMEÇO, EXPLORAÇÃO E ANÁLISE**

# %%
import pandas as pd

# %%
path = "/content/BR_CSV.txt"
df = pd.read_csv(path, sep=',')

# %%
df.head(50)
# Out:
#     id_relato blob_foto                                   ds_relato  \
# 0           1  0x1A2B3C                   Lixo espalhado pela areia
# 1           2  0x2B3C4D            Tartaruga presa em rede de pesca
# 2           3  0x3C4D5E          Grande quantidade de lixo na praia
# 3           4  0x4D5E6F               Golfinhos encalhados na praia
# 4           5  0x5E6F7G             Sacos de lixo deixados na areia
# 5           6  0x6F7G8H                 Ave marinha ferida na praia
# 6           7  0x7G8H9I                 Resíduos plásticos na areia
# 7           8  0x8H9I0J  Concentração de águas-vivas perto da costa
# 8           9  0x9I0J1K     Lixo e tartaruga presa em rede de pesca
# 9          10  0x0J1K2L                   Lixo espalhado pela areia
# 10         11  0x1K2L3M          Grande quantidade de lixo na praia
# 11         12  0x2L3M4N               Golfinhos encalhados na praia
# 12         13  0x3M4N5O             Sacos de lixo deixados na areia
# ...

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# Supondo que o DataFrame df já esteja carregado com os dados fornecidos

def plot_map_markers(data):
    # Pega latitude e longitude
    latitude = data['nr_latitude'].tolist()
    longitude = data['nr_longitude'].tolist()
    descricao = data['ds_relato'].tolist()

    # Define início das coordenadas
    start_coords = [latitude[0], longitude[0]]

    # Cria o mapa
    m = folium.Map(location=start_coords, zoom_start=12)

    # Cria um MarkerCluster
    marker_cluster = MarkerCluster().add_to(m)

    # Adiciona os markers ao cluster
    for lat, lon, desc in zip(latitude, longitude, descricao):
        folium.Marker(
            location=[lat, lon],
            popup=desc
        ).add_to(marker_cluster)

    return m

# Chama a função do mapa
map_with_markers = plot_map_markers(df)

# Exibe o mapa com markers
map_with_markers.save("map_with_markers.html")

map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df['nr_latitude']
# Out:
# 0      -2.5333
# 1     -12.9714
# 2      -7.1150
# 3     -22.9068
# 4     -16.4090
#         ...
# 195    -2.5333
# 196   -12.9714
# 197    -7.1150
# 198   -22.9068
# 199   -16.4090
# Name: nr_latitude, Length: 200, dtype: float64

# %%
df['nr_longitude']
# Out:
# 0     -44.3028
# 1     -38.5014
# 2     -34.8631
# 3     -43.1729
# 4     -39.0713
#         ...
# 195   -44.3028
# 196   -38.5014
# 197   -34.8631
# 198   -43.1729
# 199   -39.0713
# Name: nr_longitude, Length: 200, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['dt_hr_relato'] = pd.to_datetime(df['dt_hr_relato'], format='%d/%m/%Y')

# %%
df['year'] = df['dt_hr_relato'].dt.year
plt.figure(figsize=(10, 6))
sns.countplot(x='year', data=df, palette='viridis')
plt.title('Distribuição de Relatos por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-100-8d70a2265ded>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='year', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='boolean_praia_suja', data=df, palette='viridis')
plt.title('Quantidade de Relatos de Praias Sujas vs. Limpos')
plt.xlabel('Praia Suja (1) vs. Limpa (0)')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-101-ef243cec14b5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='boolean_praia_suja', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='boolean_envolve_animais', data=df, palette='viridis')
plt.title('Quantidade de Relatos Envolvendo Animais')
plt.xlabel('Envolve Animais (1) vs. Não Envolve (0)')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-102-c7d4a2e7bd2f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='boolean_envolve_animais', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['nr_longitude'], df['nr_latitude'], c='blue', alpha=0.5)
plt.title('Distribuição Geográfica dos Relatos')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='boolean_praia_suja', y='nr_likes', data=df, palette='viridis')
plt.title('Número de Likes por Tipo de Relato')
plt.xlabel('Praia Suja (1) vs. Limpa (0)')
plt.ylabel('Número de Likes')
plt.show()
# Out:
# <ipython-input-104-2c52898b31bc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='boolean_praia_suja', y='nr_likes', data=df, palette='viridis')

# %%
df['year'] = df['dt_hr_relato'].dt.year
plt.figure(figsize=(10, 6))
sns.boxplot(x='year', y='nr_likes', data=df, palette='viridis')
plt.title('Distribuição de Likes por Ano')
plt.xlabel('Ano')
plt.ylabel('Número de Likes')
plt.show()
# Out:
# <ipython-input-105-06fa75fe5509>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year', y='nr_likes', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='nr_longitude', y='nr_latitude', hue='boolean_praia_suja', data=df, palette='viridis')
plt.title('Correlação entre Latitude e Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Praia Suja')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='id_usuario', data=df, palette='viridis', order=df['id_usuario'].value_counts().index)
plt.title('Quantidade de Relatos por Usuário')
plt.xlabel('ID do Usuário')
plt.ylabel('Quantidade de Relatos')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-107-214af27d8e35>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='id_usuario', data=df, palette='viridis', order=df['id_usuario'].value_counts().index)

# %%
df['month'] = df['dt_hr_relato'].dt.month
plt.figure(figsize=(10, 6))
sns.countplot(x='month', data=df, palette='viridis')
plt.title('Distribuição de Relatos por Mês')
plt.xlabel('Mês')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-108-d4670e3f07cf>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='month', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='boolean_praia_suja', hue='boolean_envolve_animais', data=df, palette='viridis')
plt.title('Número de Relatos por Tipo de Relato (Praia Suja e Envolve Animais)')
plt.xlabel('Praia Suja (1) vs. Limpa (0)')
plt.ylabel('Quantidade de Relatos')
plt.legend(title='Envolve Animais')
plt.show()

# %%
df = df.drop(columns=['ds_relato', 'blob_foto', 'id_usuario', 'id_relato'])
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriz de Correlação')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='nr_longitude', y='nr_latitude', hue='boolean_praia_suja', palette='coolwarm', s=100)
plt.title('Localização dos Relatos - Praia Suja')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Praia Suja', loc='upper right', labels=['Não', 'Sim'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='nr_longitude', y='nr_latitude', hue='boolean_envolve_animais', palette='viridis', s=100)
plt.title('Localização dos Relatos - Envolve Animais')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Envolve Animais', loc='upper right', labels=['Não', 'Sim'])
plt.show()

# %%
import pandas as pd

duplicated_locations = df[df.duplicated(subset=['nr_latitude', 'nr_longitude'], keep=False)]

print("Coordenadas duplicadas:")
print(duplicated_locations[['nr_latitude', 'nr_longitude']])
# Out:
# Coordenadas duplicadas:
#      nr_latitude  nr_longitude
# 0        -2.5307      -44.3068
# 1        -3.7172      -38.5434
# 2        -4.9055      -37.3676
# 3        -5.7945      -35.2110
# 4        -6.8885      -38.5593
# ..           ...           ...
# 195     -17.6868      -39.2562
# 196     -18.9100      -48.2754
# 197     -19.9245      -43.9352
# 198     -20.3155      -40.3128
# 199     -21.7622      -41.3273
#
# [200 rows x 2 columns]

# %%
df['nr_longitude'].count()
# Out:
# 200

# %%
duplicated_coords = duplicated_locations[['nr_latitude', 'nr_longitude']].drop_duplicates()
print("Coordenadas duplicadas (sem repetição):")
print(duplicated_coords)
# Out:
# Coordenadas duplicadas (sem repetição):
#     nr_latitude  nr_longitude
# 0       -2.5307      -44.3068
# 1       -3.7172      -38.5434
# 2       -4.9055      -37.3676
# 3       -5.7945      -35.2110
# 4       -6.8885      -38.5593
# 5       -7.1195      -34.8450
# 6       -8.0476      -34.8770
# 7       -9.6658      -35.7353
# 8      -10.9472      -37.0731
# 9      -11.4099      -41.2809
# 10     -12.9714      -38.5014
# 11     -13.0041      -38.4946
# 12     -14.2350      -51.9253
# 13     -15.7801      -47.9292
# 14     -16.3285      -39.5800
# 15     -17.6868      -39.2562
# 16     -18.9100      -48.2754
# 17     -19.9245      -43.9352
# 18     -20.3155      -40.3128
# 19     -21.7622      -41.3273
# 20     -22.9068      -43.1729
# 21     -23.5505      -46.6333
# 22     -24.0032      -46.4124
# 23     -25.4284      -49.2733
# 24     -26.3044      -48.8464
# 25     -27.5954      -48.5480
# 26     -28.2636      -48.6664
# 27     -29.3759      -49.7234
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.figure(figsize=(10, 6))
plt.scatter(df['nr_latitude'], df['nr_longitude'])
plt.ylabel('Latitude')
plt.show()

# %%
import plotly.express as px
x=df['nr_longitude']
y=df['nr_latitude']
x_limited = x[:200]
y_limited = y[:200]
px.scatter(x=x_limited, y=y_limited, title='Gráfico de Dispersão com Plotly')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['nr_longitude'], df['nr_latitude'], c='blue', s=50, alpha=1)
plt.title('Distribuição Geográfica dos Relatos')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['nr_longitude'], df['nr_latitude'], c='blue', s=100, edgecolor='black', alpha=0.7)
plt.title('Distribuição Geográfica dos Relatos')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# # **Novos testes**

# %%
path = "/content/BR_CSV.txt"
df = pd.read_csv(path, sep=',')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df['dt_hr_relato'] = pd.to_datetime(df['dt_hr_relato'], format='%d/%m/%Y')

# %%
print(df.isnull().sum())
# Out:
# id_relato                  0
# blob_foto                  0
# ds_relato                  0
# nr_latitude                0
# nr_longitude               0
# boolean_praia_suja         0
# boolean_envolve_animais    0
# dt_hr_relato               0
# nr_likes                   0
# id_usuario                 0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='boolean_praia_suja', data=df)
plt.title('Distribuição de Ocorrências de Lixo')
plt.show()

plt.figure(figsize=(12, 6))
sns.countplot(x='boolean_envolve_animais', data=df)
plt.title('Distribuição de Ocorrências Envolvendo Animais')
plt.show()

# %%
X = df[['nr_latitude', 'nr_longitude', 'nr_likes']]
y_lixo = df['boolean_praia_suja']
y_animais = df['boolean_envolve_animais']

# %%
X_train_lixo, X_test_lixo, y_train_lixo, y_test_lixo = train_test_split(X, y_lixo, test_size=0.3, random_state=42)
X_train_animais, X_test_animais, y_train_animais, y_test_animais = train_test_split(X, y_animais, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_lixo = scaler.fit_transform(X_train_lixo)
X_test_lixo = scaler.transform(X_test_lixo)
X_train_animais = scaler.fit_transform(X_train_animais)
X_test_animais = scaler.transform(X_test_animais)

# %%
model_lixo = RandomForestClassifier(n_estimators=100, random_state=42)
model_lixo.fit(X_train_lixo, y_train_lixo)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model_animais = RandomForestClassifier(n_estimators=100, random_state=42)
model_animais.fit(X_train_animais, y_train_animais)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_lixo = model_lixo.predict(X_test_lixo)
print("Relatório de Classificação para Previsão de Lixo:")
print(classification_report(y_test_lixo, y_pred_lixo))
print("Matriz de Confusão para Previsão de Lixo:")
print(confusion_matrix(y_test_lixo, y_pred_lixo))
print("Acurácia para Previsão de Lixo:", accuracy_score(y_test_lixo, y_pred_lixo))
# Out:
# Relatório de Classificação para Previsão de Lixo:
#               precision    recall  f1-score   support
#
#            0       0.10      0.10      0.10        21
#            1       0.53      0.54      0.53        39
#
#     accuracy                           0.38        60
#    macro avg       0.31      0.32      0.31        60
# weighted avg       0.38      0.38      0.38        60
#
# Matriz de Confusão para Previsão de Lixo:
# [[ 2 19]
#  [18 21]]
# Acurácia para Previsão de Lixo: 0.38333333333333336

# %%
y_pred_animais = model_animais.predict(X_test_animais)
print("Relatório de Classificação para Previsão de Ocorrências com Animais:")
print(classification_report(y_test_animais, y_pred_animais))
print("Matriz de Confusão para Previsão de Ocorrências com Animais:")
print(confusion_matrix(y_test_animais, y_pred_animais))
print("Acurácia para Previsão de Ocorrências com Animais:", accuracy_score(y_test_animais, y_pred_animais))
# Out:
# Relatório de Classificação para Previsão de Ocorrências com Animais:
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52        32
#            1       0.42      0.39      0.41        28
#
#     accuracy                           0.47        60
#    macro avg       0.46      0.46      0.46        60
# weighted avg       0.46      0.47      0.46        60
#
# Matriz de Confusão para Previsão de Ocorrências com Animais:
# [[17 15]
#  [17 11]]
# Acurácia para Previsão de Ocorrências com Animais: 0.4666666666666667

# %%
correlation_matrix = df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-68bbfff3c4eb> in <cell line: 1>()
# ----> 1 correlation_matrix = df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # **GERAÇÃO DE DADOS**

# %%
lat1, lon1 = -25.718018, -48.751337
lat2, lon2 = -23.877286, -46.427888

num_pontos = 20

incremento_lat = (lat2 - lat1) / (num_pontos - 1)
incremento_lon = (lon2 - lon1) / (num_pontos - 1)

coordenadas = []

for i in range(num_pontos):
    lat = lat1 + i * incremento_lat
    lon = lon1 + i * incremento_lon
    coordenadas.append((lat, lon))

for i, (lat, lon) in enumerate(coordenadas):
    print(f"Latitude = {lat}, Longitude = {lon}")
# Out:
# Latitude = -25.718018, Longitude = -48.751337
# Latitude = -25.621137368421053, Longitude = -48.629050210526316
# Latitude = -25.524256736842105, Longitude = -48.50676342105263
# Latitude = -25.427376105263157, Longitude = -48.38447663157895
# Latitude = -25.330495473684213, Longitude = -48.262189842105265
# Latitude = -25.233614842105265, Longitude = -48.13990305263158
# Latitude = -25.136734210526317, Longitude = -48.0176162631579
# Latitude = -25.03985357894737, Longitude = -47.895329473684214
# Latitude = -24.94297294736842, Longitude = -47.77304268421053
# Latitude = -24.846092315789473, Longitude = -47.65075589473685
# Latitude = -24.74921168421053, Longitude = -47.528469105263156
# Latitude = -24.65233105263158, Longitude = -47.40618231578947
# Latitude = -24.555450421052633, Longitude = -47.28389552631579
# Latitude = -24.458569789473685, Longitude = -47.161608736842105
# Latitude = -24.361689157894737, Longitude = -47.03932194736842
# ...

# %%
lat1, lon1 = -32.761869, -52.907420
lat2, lon2 = -25.582574, -48.569833

num_pontos = 40

incremento_lat = (lat2 - lat1) / (num_pontos - 1)
incremento_lon = (lon2 - lon1) / (num_pontos - 1)

coordenadas = []

for i in range(num_pontos):
    lat = lat1 + i * incremento_lat
    lon = lon1 + i * incremento_lon
    coordenadas.append((lat, lon))

for i, (lat, lon) in enumerate(coordenadas):
    print(f"Latitude = {lat}, Longitude = {lon}")
# Out:
# Latitude = -32.761869, Longitude = -52.90742
# Latitude = -32.57778451282051, Longitude = -52.796199820512825
# Latitude = -32.393700025641024, Longitude = -52.68497964102564
# Latitude = -32.209615538461534, Longitude = -52.573759461538465
# Latitude = -32.02553105128205, Longitude = -52.46253928205128
# Latitude = -31.84144656410256, Longitude = -52.351319102564105
# Latitude = -31.657362076923075, Longitude = -52.24009892307693
# Latitude = -31.47327758974359, Longitude = -52.128878743589745
# Latitude = -31.289193102564102, Longitude = -52.01765856410257
# Latitude = -31.105108615384612, Longitude = -51.906438384615385
# Latitude = -30.921024128205126, Longitude = -51.79521820512821
# Latitude = -30.73693964102564, Longitude = -51.68399802564103
# Latitude = -30.552855153846153, Longitude = -51.57277784615385
# Latitude = -30.368770666666666, Longitude = -51.46155766666667
# Latitude = -30.18468617948718, Longitude = -51.35033748717949
# ...

# %%
lat1, lon1 = -22.853978, -42.243931
lat2, lon2 = -15.613099, -39.012232

num_pontos = 60

incremento_lat = (lat2 - lat1) / (num_pontos - 1)
incremento_lon = (lon2 - lon1) / (num_pontos - 1)

coordenadas = []

for i in range(num_pontos):
    lat = lat1 + i * incremento_lat
    lon = lon1 + i * incremento_lon
    coordenadas.append((lat, lon))

for i, (lat, lon) in enumerate(coordenadas):
    print(f"Latitude = {lat}, Longitude = {lon}")
# Out:
# Latitude = -22.853978, Longitude = -42.243931
# Latitude = -22.731251237288138, Longitude = -42.18915644067797
# Latitude = -22.608524474576274, Longitude = -42.134381881355935
# Latitude = -22.485797711864407, Longitude = -42.0796073220339
# Latitude = -22.363070949152544, Longitude = -42.02483276271187
# Latitude = -22.24034418644068, Longitude = -41.97005820338983
# Latitude = -22.117617423728817, Longitude = -41.9152836440678
# Latitude = -21.99489066101695, Longitude = -41.860509084745765
# Latitude = -21.872163898305086, Longitude = -41.80573452542373
# Latitude = -21.749437135593222, Longitude = -41.750959966101696
# Latitude = -21.62671037288136, Longitude = -41.69618540677966
# Latitude = -21.50398361016949, Longitude = -41.64141084745763
# Latitude = -21.381256847457628, Longitude = -41.586636288135594
# Latitude = -21.258530084745765, Longitude = -41.53186172881356
# Latitude = -21.1358033220339, Longitude = -41.477087169491526
# ...

# %%
lat1, lon1 = -12.993720, -38.763640
lat2, lon2 = -7.091093, -34.863850

num_pontos = 50

incremento_lat = (lat2 - lat1) / (num_pontos - 1)
incremento_lon = (lon2 - lon1) / (num_pontos - 1)

coordenadas = []

for i in range(num_pontos):
    lat = lat1 + i * incremento_lat
    lon = lon1 + i * incremento_lon
    coordenadas.append((lat, lon))

for i, (lat, lon) in enumerate(coordenadas):
    print(f"Latitude = {lat}, Longitude = {lon}")
# Out:
# Latitude = -12.99372, Longitude = -38.76364
# Latitude = -12.873258224489796, Longitude = -38.68405244897959
# Latitude = -12.752796448979591, Longitude = -38.60446489795918
# Latitude = -12.632334673469387, Longitude = -38.52487734693878
# Latitude = -12.511872897959183, Longitude = -38.44528979591837
# Latitude = -12.391411122448979, Longitude = -38.36570224489796
# Latitude = -12.270949346938774, Longitude = -38.28611469387755
# Latitude = -12.15048757142857, Longitude = -38.20652714285715
# Latitude = -12.030025795918368, Longitude = -38.12693959183674
# Latitude = -11.909564020408164, Longitude = -38.04735204081633
# Latitude = -11.78910224489796, Longitude = -37.96776448979592
# Latitude = -11.668640469387755, Longitude = -37.88817693877551
# Latitude = -11.548178693877551, Longitude = -37.808589387755106
# Latitude = -11.427716918367347, Longitude = -37.729001836734696
# Latitude = -11.307255142857143, Longitude = -37.649414285714286
# ...

# %%
lat1, lon1 = -6.952309, -34.910461
lat2, lon2 = -3.781596, -38.685955

num_pontos = 30

incremento_lat = (lat2 - lat1) / (num_pontos - 1)
incremento_lon = (lon2 - lon1) / (num_pontos - 1)

coordenadas = []

for i in range(num_pontos):
    lat = lat1 + i * incremento_lat
    lon = lon1 + i * incremento_lon
    coordenadas.append((lat, lon))

for i, (lat, lon) in enumerate(coordenadas):
    print(f"Latitude = {lat}, Longitude = {lon}")
# Out:
# Latitude = -6.952309, Longitude = -34.910461
# Latitude = -6.842974068965517, Longitude = -35.04065044827586
# Latitude = -6.733639137931034, Longitude = -35.17083989655172
# Latitude = -6.624304206896552, Longitude = -35.30102934482758
# Latitude = -6.514969275862069, Longitude = -35.43121879310345
# Latitude = -6.405634344827586, Longitude = -35.56140824137931
# Latitude = -6.296299413793103, Longitude = -35.69159768965517
# Latitude = -6.18696448275862, Longitude = -35.82178713793103
# Latitude = -6.077629551724137, Longitude = -35.9519765862069
# Latitude = -5.9682946206896546, Longitude = -36.08216603448275
# Latitude = -5.8589596896551726, Longitude = -36.21235548275862
# Latitude = -5.74962475862069, Longitude = -36.34254493103448
# Latitude = -5.640289827586207, Longitude = -36.472734379310346
# Latitude = -5.530954896551724, Longitude = -36.6029238275862
# Latitude = -5.421619965517241, Longitude = -36.73311327586207
# ...

# %% [markdown]
# # **CÓDIGO REAL**

# %%
path = "/content/BR_CSV_TESTE.txt"
df = pd.read_csv(path, sep=',')

# %%
df.head(20)
# Out:
#     id_relato blob_foto                                   ds_relato  \
# 0           1  0x1A2B3C                   Lixo espalhado pela areia
# 1           2  0x2B3C4D            Tartaruga presa em rede de pesca
# 2           3  0x3C4D5E          Grande quantidade de lixo na praia
# 3           4  0x4D5E6F               Golfinhos encalhados na praia
# 4           5  0x5E6F7G             Sacos de lixo deixados na areia
# 5           6  0x6F7G8H                 Ave marinha ferida na praia
# 6           7  0x7G8H9I                 Resíduos plásticos na areia
# 7           8  0x8H9I0J  Concentração de águas-vivas perto da costa
# 8           9  0x9I0J1K     Lixo e tartaruga presa em rede de pesca
# 9          10  0x0J1K2L                   Lixo espalhado pela areia
# 10         11  0x1K2L3M          Grande quantidade de lixo na praia
# 11         12  0x2L3M4N               Golfinhos encalhados na praia
# 12         13  0x3M4N5O             Sacos de lixo deixados na areia
# ...

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

def plot_map_markers(data):
    latitude = data['nr_latitude'].tolist()
    longitude = data['nr_longitude'].tolist()
    descricao = data['ds_relato'].tolist()
    praia_suja = data['boolean_praia_suja'].tolist()
    envolve_animais = data['boolean_envolve_animais'].tolist()

    start_coords = [latitude[0], longitude[0]]

    m = folium.Map(location=start_coords, zoom_start=12)

    marker_cluster = MarkerCluster().add_to(m)

    for lat, lon, desc, suja, animais in zip(latitude, longitude, descricao, praia_suja, envolve_animais):
        if suja and animais:
            color = 'purple'  # Ambos
        elif suja:
            color = 'red'  # Praia suja
        elif animais:
            color = 'blue'  # Envolve animais
        else:
            color = 'green'

        folium.Marker(
            location=[lat, lon],
            popup=desc,
            icon=folium.Icon(color=color)
        ).add_to(marker_cluster)

    return m

map_with_markers = plot_map_markers(df)

map_with_markers.save("map_with_markers.html")

map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='nr_longitude', y='nr_latitude', hue='boolean_envolve_animais', palette='viridis', s=100)
plt.title('Localização dos Relatos - Envolve Animais')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Envolve Animais', loc='upper right', labels=['Não', 'Sim'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='nr_longitude', y='nr_latitude', hue='boolean_praia_suja', palette='coolwarm', s=100)
plt.title('Localização dos Relatos - Praia Suja')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Praia Suja', loc='upper right', labels=['Não', 'Sim'])
plt.show()

# %%
import plotly.express as px
x=df['nr_longitude']
y=df['nr_latitude']
x_limited = x[:200]
y_limited = y[:200]
px.scatter(x=x_limited, y=y_limited, title='Gráfico de Dispersão com Plotly')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['dt_hr_relato'] = pd.to_datetime(df['dt_hr_relato'], format='%d/%m/%Y')

# %%
df['month'] = df['dt_hr_relato'].dt.month
plt.figure(figsize=(10, 6))
sns.countplot(x='month', data=df, palette='viridis')
plt.title('Distribuição de Relatos por Mês')
plt.xlabel('Mês')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-90-d4670e3f07cf>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='boolean_praia_suja', hue='boolean_envolve_animais', data=df, palette='viridis')
plt.title('Número de Relatos por Tipo de Relato (Praia Suja e Envolve Animais)')
plt.xlabel('Praia Suja (1) vs. Limpa (0)')
plt.ylabel('Quantidade de Relatos')
plt.legend(title='Envolve Animais')
plt.show()

# %%
df['year'] = df['dt_hr_relato'].dt.year
plt.figure(figsize=(10, 6))
sns.countplot(x='year', data=df, palette='viridis')
plt.title('Distribuição de Relatos por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Relatos')
plt.show()
# Out:
# <ipython-input-92-8d70a2265ded>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
columns_to_drop = ['id_relato', 'blob_foto', 'ds_relato', 'dt_hr_relato', 'id_usuario']
df_cleaned = df.drop(columns=columns_to_drop)

# %%
print(df_cleaned.head())
# Out:
#    nr_latitude  nr_longitude  boolean_praia_suja  boolean_envolve_animais  \
# 0   -25.718018    -48.751337                   1                        0
# 1   -25.621137    -48.629050                   0                        1
# 2   -25.524257    -48.506763                   1                        0
# 3   -25.427376    -48.384477                   0                        1
# 4   -25.330495    -48.262190                   1                        0
#
#    nr_likes
# 0        45
# 1        67
# 2        23
# 3        89
# 4        12

# %%
correlation_matrix = df_cleaned.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlação')
plt.show()

# %%
df_cleaned['latitude_interval'] = pd.cut(df_cleaned['nr_latitude'], bins=10)
df_cleaned['longitude_interval'] = pd.cut(df_cleaned['nr_longitude'], bins=10)

# %%
lixo_counts = df_cleaned[df_cleaned['boolean_praia_suja'] == 1].groupby(['latitude_interval', 'longitude_interval']).size().unstack(fill_value=0)

# %%
animais_counts = df_cleaned[df_cleaned['boolean_envolve_animais'] == 1].groupby(['latitude_interval', 'longitude_interval']).size().unstack(fill_value=0)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(lixo_counts, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Ocorrências de Lixo por Intervalo de Latitude e Longitude')
plt.xlabel('Intervalo de Longitude')
plt.ylabel('Intervalo de Latitude')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(animais_counts, annot=True, cmap='YlOrRd', linewidths=0.5)
plt.title('Ocorrências Envolvendo Animais por Intervalo de Latitude e Longitude')
plt.xlabel('Intervalo de Longitude')
plt.ylabel('Intervalo de Latitude')
plt.show()

# %%
X = df_cleaned[['nr_latitude', 'nr_longitude', 'nr_likes']]
y_lixo = df_cleaned['boolean_praia_suja']
y_animais = df_cleaned['boolean_envolve_animais']

# %%
X_train_lixo, X_test_lixo, y_train_lixo, y_test_lixo = train_test_split(X, y_lixo, test_size=0.3, random_state=42)
X_train_animais, X_test_animais, y_train_animais, y_test_animais = train_test_split(X, y_animais, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_lixo = scaler.fit_transform(X_train_lixo)
X_test_lixo = scaler.transform(X_test_lixo)
X_train_animais = scaler.fit_transform(X_train_animais)
X_test_animais = scaler.transform(X_test_animais)

# %%
model_lixo = RandomForestClassifier(n_estimators=100, random_state=42)
model_lixo.fit(X_train_lixo, y_train_lixo)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model_animais = RandomForestClassifier(n_estimators=100, random_state=42)
model_animais.fit(X_train_animais, y_train_animais)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_lixo = model_lixo.predict(X_test_lixo)
print("Relatório de Classificação para Previsão de Lixo:")
print(classification_report(y_test_lixo, y_pred_lixo))
print("Matriz de Confusão para Previsão de Lixo:")
print(confusion_matrix(y_test_lixo, y_pred_lixo))
print("Acurácia para Previsão de Lixo:", accuracy_score(y_test_lixo, y_pred_lixo))
# Out:
# Relatório de Classificação para Previsão de Lixo:
#               precision    recall  f1-score   support
#
#            0       0.12      0.10      0.11        21
#            1       0.56      0.62      0.59        39
#
#     accuracy                           0.43        60
#    macro avg       0.34      0.36      0.35        60
# weighted avg       0.40      0.43      0.42        60
#
# Matriz de Confusão para Previsão de Lixo:
# [[ 2 19]
#  [15 24]]
# Acurácia para Previsão de Lixo: 0.43333333333333335

# %%
y_pred_animais = model_animais.predict(X_test_animais)
print("Relatório de Classificação para Previsão de Ocorrências com Animais:")
print(classification_report(y_test_animais, y_pred_animais))
print("Matriz de Confusão para Previsão de Ocorrências com Animais:")
print(confusion_matrix(y_test_animais, y_pred_animais))
print("Acurácia para Previsão de Ocorrências com Animais:", accuracy_score(y_test_animais, y_pred_animais))
# Out:
# Relatório de Classificação para Previsão de Ocorrências com Animais:
#               precision    recall  f1-score   support
#
#            0       0.26      0.22      0.24        32
#            1       0.24      0.29      0.26        28
#
#     accuracy                           0.25        60
#    macro avg       0.25      0.25      0.25        60
# weighted avg       0.25      0.25      0.25        60
#
# Matriz de Confusão para Previsão de Ocorrências com Animais:
# [[ 7 25]
#  [20  8]]
# Acurácia para Previsão de Ocorrências com Animais: 0.25

# %%
print("Áreas com alta incidência de lixo:")
print(lixo_counts[lixo_counts > 0])
# Out:
# Áreas com alta incidência de lixo:
# longitude_interval  (-52.925, -51.103]  (-51.103, -49.299]  \
# latitude_interval
# (-32.791, -29.864]                10.0                 NaN
# (-29.864, -26.966]                 1.0                 9.0
# (-26.966, -24.068]                 NaN                 1.0
# (-24.068, -21.17]                  NaN                 NaN
# (-21.17, -18.272]                  NaN                 NaN
# (-18.272, -15.374]                 NaN                 NaN
# (-15.374, -12.476]                 NaN                 NaN
# (-12.476, -9.578]                  NaN                 NaN
# (-9.578, -6.68]                    NaN                 NaN
# (-6.68, -3.782]                    NaN                 NaN
#
# longitude_interval  (-49.299, -47.494]  (-47.494, -45.69]  (-45.69, -43.886]  \
# latitude_interval
# (-32.791, -29.864]                 NaN                NaN                NaN
# (-29.864, -26.966]                 NaN                NaN                NaN
# ...

# %%
print("Áreas com alta incidência de ocorrências envolvendo animais:")
print(animais_counts[animais_counts > 0])
# Out:
# Áreas com alta incidência de ocorrências envolvendo animais:
# longitude_interval  (-52.925, -51.103]  (-51.103, -49.299]  \
# latitude_interval
# (-32.791, -29.864]                 8.0                 NaN
# (-29.864, -26.966]                 NaN                 8.0
# (-26.966, -24.068]                 NaN                 NaN
# (-24.068, -21.17]                  NaN                 NaN
# (-21.17, -18.272]                  NaN                 NaN
# (-18.272, -15.374]                 NaN                 NaN
# (-15.374, -12.476]                 NaN                 NaN
# (-12.476, -9.578]                  NaN                 NaN
# (-9.578, -6.68]                    NaN                 NaN
# (-6.68, -3.782]                    NaN                 NaN
#
# longitude_interval  (-49.299, -47.494]  (-47.494, -45.69]  (-45.69, -43.886]  \
# latitude_interval
# (-32.791, -29.864]                 NaN                NaN                NaN
# ...

# %% [markdown]
# # **OUTRO CÓDIGO**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df_cleaned['latitude_interval'] = pd.cut(df_cleaned['nr_latitude'], bins=10)
df_cleaned['longitude_interval'] = pd.cut(df_cleaned['nr_longitude'], bins=10)

# %%
lixo_counts = df_cleaned[df_cleaned['boolean_praia_suja'] == 1].groupby(['latitude_interval', 'longitude_interval']).size().unstack(fill_value=0)

# %%
animais_counts = df_cleaned[df_cleaned['boolean_envolve_animais'] == 1].groupby(['latitude_interval', 'longitude_interval']).size().unstack(fill_value=0)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(lixo_counts, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Ocorrências de Lixo por Intervalo de Latitude e Longitude')
plt.xlabel('Intervalo de Longitude')
plt.ylabel('Intervalo de Latitude')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(animais_counts, annot=True, cmap='YlOrRd', linewidths=0.5)
plt.title('Ocorrências Envolvendo Animais por Intervalo de Latitude e Longitude')
plt.xlabel('Intervalo de Longitude')
plt.ylabel('Intervalo de Latitude')
plt.show()

# %%
X = df_cleaned[['nr_latitude', 'nr_longitude', 'nr_likes']]
y_lixo = df_cleaned['boolean_praia_suja']
y_animais = df_cleaned['boolean_envolve_animais']

# %%
X_train_lixo, X_test_lixo, y_train_lixo, y_test_lixo = train_test_split(X, y_lixo, test_size=0.3, random_state=42)
X_train_animais, X_test_animais, y_train_animais, y_test_animais = train_test_split(X, y_animais, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_lixo = scaler.fit_transform(X_train_lixo)
X_test_lixo = scaler.transform(X_test_lixo)
X_train_animais = scaler.fit_transform(X_train_animais)
X_test_animais = scaler.transform(X_test_animais)

# %%
def train_and_evaluate_model(model, X_train, X_test, y_train, y_test, model_name):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"Relatório de Classificação para {model_name}:")
    print(classification_report(y_test, y_pred))
    print(f"Matriz de Confusão para {model_name}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"Acurácia para {model_name}: {accuracy_score(y_test, y_pred)}\n")

# %%
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Support Vector Machine": SVC(random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42)
}

# %%
print("Previsão de Lixo:\n")
for model_name, model in models.items():
    train_and_evaluate_model(model, X_train_lixo, X_test_lixo, y_train_lixo, y_test_lixo, model_name)
# Out:
# Previsão de Lixo:
#
# Relatório de Classificação para Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        21
#            1       0.65      1.00      0.79        39
#
#     accuracy                           0.65        60
#    macro avg       0.33      0.50      0.39        60
# weighted avg       0.42      0.65      0.51        60
#
# Matriz de Confusão para Logistic Regression:
# [[ 0 21]
#  [ 0 39]]
# Acurácia para Logistic Regression: 0.65
#
# Relatório de Classificação para Support Vector Machine:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        21
#            1       0.65      1.00      0.79        39
#
#     accuracy                           0.65        60
#    macro avg       0.33      0.50      0.39        60
# weighted avg       0.42      0.65      0.51        60
#
# Matriz de Confusão para Support Vector Machine:
# [[ 0 21]
# ...

# %%
print("Previsão de Ocorrências com Animais:\n")
for model_name, model in models.items():
    train_and_evaluate_model(model, X_train_animais, X_test_animais, y_train_animais, y_test_animais, model_name)
# Out:
# Previsão de Ocorrências com Animais:
#
# Relatório de Classificação para Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.18      0.06      0.09        32
#            1       0.39      0.68      0.49        28
#
#     accuracy                           0.35        60
#    macro avg       0.28      0.37      0.29        60
# weighted avg       0.28      0.35      0.28        60
#
# Matriz de Confusão para Logistic Regression:
# [[ 2 30]
#  [ 9 19]]
# Acurácia para Logistic Regression: 0.35
#
# Relatório de Classificação para Support Vector Machine:
#               precision    recall  f1-score   support
#
#            0       0.32      0.22      0.26        32
#            1       0.34      0.46      0.39        28
#
#     accuracy                           0.33        60
#    macro avg       0.33      0.34      0.33        60
# weighted avg       0.33      0.33      0.32        60
#
# ...

# %%
print("Áreas com alta incidência de lixo:")
print(lixo_counts[lixo_counts > 0])
# Out:
# Áreas com alta incidência de lixo:
# longitude_interval  (-52.925, -51.103]  (-51.103, -49.299]  \
# latitude_interval
# (-32.791, -29.864]                10.0                 NaN
# (-29.864, -26.966]                 1.0                 9.0
# (-26.966, -24.068]                 NaN                 1.0
# (-24.068, -21.17]                  NaN                 NaN
# (-21.17, -18.272]                  NaN                 NaN
# (-18.272, -15.374]                 NaN                 NaN
# (-15.374, -12.476]                 NaN                 NaN
# (-12.476, -9.578]                  NaN                 NaN
# (-9.578, -6.68]                    NaN                 NaN
# (-6.68, -3.782]                    NaN                 NaN
#
# longitude_interval  (-49.299, -47.494]  (-47.494, -45.69]  (-45.69, -43.886]  \
# latitude_interval
# (-32.791, -29.864]                 NaN                NaN                NaN
# (-29.864, -26.966]                 NaN                NaN                NaN
# ...

# %%
print("Áreas com alta incidência de ocorrências envolvendo animais:")
print(animais_counts[animais_counts > 0])
# Out:
# Áreas com alta incidência de ocorrências envolvendo animais:
# longitude_interval  (-52.925, -51.103]  (-51.103, -49.299]  \
# latitude_interval
# (-32.791, -29.864]                 8.0                 NaN
# (-29.864, -26.966]                 NaN                 8.0
# (-26.966, -24.068]                 NaN                 NaN
# (-24.068, -21.17]                  NaN                 NaN
# (-21.17, -18.272]                  NaN                 NaN
# (-18.272, -15.374]                 NaN                 NaN
# (-15.374, -12.476]                 NaN                 NaN
# (-12.476, -9.578]                  NaN                 NaN
# (-9.578, -6.68]                    NaN                 NaN
# (-6.68, -3.782]                    NaN                 NaN
#
# longitude_interval  (-49.299, -47.494]  (-47.494, -45.69]  (-45.69, -43.886]  \
# latitude_interval
# (-32.791, -29.864]                 NaN                NaN                NaN
# ...
